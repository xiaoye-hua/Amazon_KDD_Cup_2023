# %% [markdown]
# # Package

# %%
import warnings
warnings.simplefilter('ignore')

import gc
import re
from collections import defaultdict, Counter

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from tqdm.auto import tqdm

# %%
# df_prod = pd.read_csv('data/products_train.csv')
# df_prod

# %% [markdown]
# # Config

# %%
debug = False

debug_session_num = 100
train_data_dir = '.'
test_data_dir = '.'
task = 'task1'
# PREDS_PER_SESSION = 100

# num_tree = 100

# model_dir = '../model_training/als_v1'

# target locales: locales needed for task1
target_locals = ["DE", 'JP', 'UK']

submit_file = f'submission_{task}_next_item_counter.parquet'

# %%
submit_file
# Out:
# 'submission_task1_next_item_counter.parquet'

# %% [markdown]
# # Data

# %%
df_sess = pd.read_csv('sessions_train.csv')
df_sess
# Out:
#                                                 prev_items   next_item locale
# 0                              ['B09W9FND7K' 'B09JSPLN1M']  B09M7GY217     DE
# 1        ['B076THCGSG' 'B007MO8IME' 'B08MF65MLV' 'B001B...  B001B4THSA     DE
# 2        ['B0B1LGXWDS' 'B00AZYORS2' 'B0B1LGXWDS' 'B00AZ...  B0767DTG2Q     DE
# 3        ['B09XMTWDVT' 'B0B4MZZ8MB' 'B0B7HZ2GWX' 'B09XM...  B0B4R9NN4B     DE
# 4                 ['B09Y5CSL3T' 'B09Y5DPTXN' 'B09FKD61R8']  B0BGVBKWGZ     DE
# ...                                                    ...         ...    ...
# 3606244           ['B086CYFSKW' 'B0874F9859' 'B086CYFSKW']  B07B5TYD76     IT
# 3606245                        ['B09NRZKZ7V' 'B08WJTPV93']  B08L1P4C3D     IT
# 3606246                        ['B085JFX7MP' 'B085JGHW8R']  B01MPWVD44     IT
# 3606247                        ['B00B0UING2' 'B00B0UING2']  B00D3HYEZ4     IT
# 3606248  ['B092S9D1SD' 'B09XQQ1S72' 'B0852MS7QC' 'B0B1V...  B0B7RX65YP     IT
#
# [3606249 rows x 3 columns]

# %%
df_test = pd.read_csv('sessions_test_task1.csv')
df_test
# Out:
#                                                prev_items locale
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE
# ...                                                   ...    ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK
#
# [316971 rows x 2 columns]

# %%
df_sess = df_sess[df_sess['locale'].isin(target_locals)]

if debug:
    df_sess = df_sess.sample(debug_session_num)
    df_test = df_test.sample(debug_session_num)

# %%
def str2list(x):
    x = x.replace('[', '').replace(']', '').replace("'", '').replace('\n', ' ').replace('\r', ' ')
    l = [i for i in x.split() if i]
    return l

# %%
df_sess.shape
# Out:
# (3272716, 3)

# %% [markdown]
# # Next Item Statistics

# %%
next_item_dict = defaultdict(list)

for _, row in tqdm(df_sess.iterrows(), total=len(df_sess)):
    prev_items = str2list(row['prev_items'])
    next_item = row['next_item']
    prev_items_length = len(prev_items)
    if prev_items_length <= 1:
        next_item_dict[prev_items[0]].append(next_item)
    else:
        for i, item in enumerate(prev_items[:-1]):
            next_item_dict[item].append(prev_items[i+1])
        next_item_dict[prev_items[-1]].append(next_item)
# Out:
#   0%|          | 0/3272716 [00:00<?, ?it/s]

# %%
# next_item_dict

# %%
for _, row in tqdm(df_test.iterrows(), total=len(df_test)):
    prev_items = str2list(row['prev_items'])
    prev_items_length = len(prev_items)
    if prev_items_length <= 1:
        continue
    else:
        for i, item in enumerate(prev_items[:-1]):
            next_item_dict[item].append(prev_items[i+1])
# Out:
#   0%|          | 0/316971 [00:00<?, ?it/s]

# %%
next_item_map = {}

for item in tqdm(next_item_dict):
    counter = Counter(next_item_dict[item])
    next_item_map[item] = [i[0] for i in counter.most_common(100)]
# Out:
#   0%|          | 0/1270206 [00:00<?, ?it/s]

# %%
# next_item_dict

# %% [markdown]
# # Top200 for fallback logics

# %%
k = []
v = []

for item in next_item_dict:
    k.append(item)
    v.append(next_item_dict[item])
    
df_next = pd.DataFrame({'item': k, 'next_item': v})
df_next = df_next.explode('next_item').reset_index(drop=True)
df_next
# Out:
#                 item   next_item
# 0         B09W9FND7K  B09JSPLN1M
# 1         B09W9FND7K  B09JSPLN1M
# 2         B09W9FND7K  B09JSPLN1M
# 3         B09W9FND7K  B09JSPLN1M
# 4         B09W9FND7K  B078WW2WN5
# ...              ...         ...
# 15132435  B0BFPLN8FQ  B0BF5GT13X
# 15132436  B09737CD6H  B08DJ9SQFY
# 15132437  B084GZ3QZ7  B00CBAW8SE
# 15132438  B081TXFKS5  B004RN5I6W
# 15132439  B07H31QX5Q  B08R7685RH
#
# [15132440 rows x 2 columns]

# %%
# df_next['next_item'].value_counts().index.tolist()[:200]

# %%
top200 = df_next['next_item'].value_counts().index.tolist()[:200]

# %% [markdown]
# # Get final result

# %%
df_test['last_item'] = df_test['prev_items'].apply(lambda x: str2list(x)[-1])
df_test['next_item_prediction'] = df_test['last_item'].map(next_item_map)
df_test
# Out:
#                                                prev_items locale   last_item  \
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE  B099NQFMG7
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE  B00R9RZ9ZS
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE  B07G7Q5N6G
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE  3955350843
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE  B09J945WQR
# ...                                                   ...    ...         ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK  B0B14M3VZX
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK  B081YDH55K
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK  B09HL11V5B
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK  B09JYZ325W
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK  B0BG2LZQSL
#
#                                      next_item_prediction
# 0       [B099NS1XPG, B08496TCCQ, B01BVG1XJS, B099NR3X6...
# 1       [B004ZXMV4Q, B00R9R5ND6, B095TQTZXY, B086J6RTT...
# 2       [B08C9Q7QVK, B07G7Q5N6G, B07YSRXJD3, B0B5QNFWJ...
# 3       [395535086X, 3955350843, B0829LZFT1, 377247695...
# 4       [B09J8V18FL, B09J8T6TTH, B09J8SKX9G, B09J8V9RQ...
# ...                                                   ...
# 316966   [B08X9L5RGD, B07V5FL8G6, B09Y4HKGKT, B09MW64JGM]
# 316967  [B0989BHLSY, B09CPNS7XV, B09895QPQF, B09CPP92Q...
# 316968  [B09HKZBNZH, B09HZSRJWW, B09HL141QC, B07PY1N81...
# 316969  [B07TR5LQSL, B08FB464L7, B09JYZ325W, B08JG8TSC...
# 316970               [B09XPX59JK, B09TN4MP6V, B08LGRK6MT]
#
# [316971 rows x 4 columns]

# %%
preds = []

for _, row in tqdm(df_test.iterrows(), total=len(df_test)):
    pred_orig = row['next_item_prediction']
    pred = pred_orig
    prev_items = str2list(row['prev_items'])
    if type(pred) == float:
        pred = top200[:100]
    else:
        if len(pred_orig) < 100:
            for i in top200:
                if i not in pred_orig and i not in prev_items:
                    pred.append(i)
                if len(pred) >= 100:
                    break
        else:
            pred = pred[:100]
    preds.append(pred)
# Out:
#   0%|          | 0/316971 [00:00<?, ?it/s]

# %%
df_test['next_item_prediction'] = preds
df_test
# Out:
#                                                prev_items locale   last_item  \
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE  B099NQFMG7
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE  B00R9RZ9ZS
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE  B07G7Q5N6G
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE  3955350843
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE  B09J945WQR
# ...                                                   ...    ...         ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK  B0B14M3VZX
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK  B081YDH55K
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK  B09HL11V5B
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK  B09JYZ325W
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK  B0BG2LZQSL
#
#                                      next_item_prediction
# 0       [B099NS1XPG, B08496TCCQ, B01BVG1XJS, B099NR3X6...
# 1       [B004ZXMV4Q, B00R9R5ND6, B095TQTZXY, B086J6RTT...
# 2       [B08C9Q7QVK, B07G7Q5N6G, B07YSRXJD3, B0B5QNFWJ...
# 3       [395535086X, 3955350843, B0829LZFT1, 377247695...
# 4       [B09J8V18FL, B09J8T6TTH, B09J8SKX9G, B09J8V9RQ...
# ...                                                   ...
# 316966  [B08X9L5RGD, B07V5FL8G6, B09Y4HKGKT, B09MW64JG...
# 316967  [B0989BHLSY, B09CPNS7XV, B09895QPQF, B09CPP92Q...
# 316968  [B09HKZBNZH, B09HZSRJWW, B09HL141QC, B07PY1N81...
# 316969  [B07TR5LQSL, B08FB464L7, B09JYZ325W, B08JG8TSC...
# 316970  [B09XPX59JK, B09TN4MP6V, B08LGRK6MT, B07QPV9Z7...
#
# [316971 rows x 4 columns]

# %%
df_test['next_item_prediction'].apply(len).describe()
# Out:
# count    316971.0
# mean        100.0
# std           0.0
# min         100.0
# 25%         100.0
# 50%         100.0
# 75%         100.0
# max         100.0
# Name: next_item_prediction, dtype: float64

# %% [markdown]
# # Submit result

# %%
df_test[['locale', 'next_item_prediction']].to_parquet(submit_file, engine='pyarrow')

# %%
# You can submit with aicrowd-cli, or upload manually on the challenge page.
# !aicrowd submission create -c task-1-next-product-recommendation -f {submit_file}
# Out:
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━━━ 0.0% • 0.0/11… • ? • -:--:--
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.7    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.7    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.8    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.8    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.8    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.8    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.0/… • 2.8    • 0:00:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.0% • 0.1/… • 339.5  • 0:05:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 387.7  • 0:05:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 434.6  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 479.9  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 523.9  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 566.3  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 607.4  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 607.4  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 371.7  • 0:05:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 395.9  • 0:05:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 420.0  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 443.8  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.1/… • 467.0  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.2/… • 489.9  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.2/… • 512.5  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.1% • 0.2/… • 534.5  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 556.3  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 577.7  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 598.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 598.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 459.1  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 474.6  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 490.3  • 0:04:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 506.0  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 521.4  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.2/… • 536.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 551.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 551.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 562.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 577.1  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 591.6  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 605.9  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.2% • 0.3/… • 620.0  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 633.9  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 647.7  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 661.2  • 0:03:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 674.5  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 687.0  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.3/… • 699.8  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.4/… • 712.7  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.4/… • 725.4  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0.3% • 0.4/… • 737.9  • 0:02:…
# submission_task1_next_item_counter.parquet ━━━━━━ 0